# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import random

# %%
SEED = 666
DATA_FILE = '../Datasets/cats/data/breeds_data_final.pkl'
IMAGES_DIR = '../Datasets/cats/images'
FIGURES_DIR = '../Figures/'
CHECKPOINTS_DIR = '../History/'
RESOLUTION = 128
LABELS = 'coat'

# %%
random.seed(SEED)
np.random.seed(SEED)

# %%
data = pd.read_pickle(DATA_FILE)
data
# Out:
#        age  gender  size  coat  breed                              image
# 3      1.0     0.0   3.0   2.0    0.0          Abyssinian/46620170_3.jpg
# 7      0.0     1.0   2.0   2.0    0.0          Abyssinian/46463847_8.jpg
# 11     2.0     1.0   2.0   2.0    0.0         Abyssinian/46305208_12.jpg
# 12     0.0     0.0   2.0   2.0    0.0         Abyssinian/46301725_13.jpg
# 13     3.0     1.0   3.0   2.0    0.0         Abyssinian/46293180_14.jpg
# ...    ...     ...   ...   ...    ...                                ...
# 67140  1.0     1.0   2.0   2.0   65.0           Tuxedo/43781057_7295.jpg
# 67141  0.0     0.0   2.0   2.0   65.0           Tuxedo/43773439_7304.jpg
# 67142  3.0     0.0   1.0   2.0   65.0           Tuxedo/43773383_7305.jpg
# 67143  0.0     1.0   2.0   1.0   65.0           Tuxedo/43773168_7306.jpg
# 67144  1.0     1.0   3.0   1.0   66.0  York Chocolate/46336858_40884.jpg
#
# [41939 rows x 6 columns]

# %%
# Cats data string convertor
# Data was collected from Analysis/cats/cats_prediction_2.ipynb
age_list = ['Adult', 'Baby', 'Senior', 'Young']
gender_list = ['Female', 'Male']
size_list = ['Extra Large', 'Large', 'Medium', 'Small']
coat_list = ['Long', 'Medium', 'Short']
breed_list = ['Abyssinian', 'American Bobtail', 'American Curl',
        'American Shorthair', 'American Wirehair', 'Applehead Siamese',
        'Balinese', 'Bengal', 'Birman', 'Bombay', 'British Shorthair',
        'Burmese', 'Burmilla', 'Calico', 'Canadian Hairless', 'Chartreux',
        'Chausie', 'Chinchilla', 'Cornish Rex', 'Cymric', 'Devon Rex',
        'Dilute Calico', 'Dilute Tortoiseshell', 'Domestic Long Hair',
        'Domestic Medium Hair', 'Domestic Short Hair', 'Egyptian Mau',
        'Exotic Shorthair', 'Extra-Toes Cat - Hemingway Polydactyl',
        'Havana', 'Himalayan', 'Japanese Bobtail', 'Javanese', 'Korat',
        'LaPerm', 'Maine Coon', 'Manx', 'Munchkin', 'Nebelung',
        'Norwegian Forest Cat', 'Ocicat', 'Oriental Long Hair',
        'Oriental Short Hair', 'Oriental Tabby', 'Persian', 'Pixiebob',
        'Ragamuffin', 'Ragdoll', 'Russian Blue', 'Scottish Fold',
        'Selkirk Rex', 'Siamese', 'Siberian', 'Silver', 'Singapura',
        'Snowshoe', 'Somali', 'Sphynx - Hairless Cat', 'Tabby', 'Tiger',
        'Tonkinese', 'Torbie', 'Tortoiseshell', 'Turkish Angora',
        'Turkish Van', 'Tuxedo', 'York Chocolate']

def get_cat_string(cat, value):
    if(cat == 'age'):
        return age_list[int(value)]
    elif(cat == 'gender'):
        return gender_list[int(value)]
    elif(cat == 'size'):
        return size_list[int(value)]
    elif(cat == 'coat'):
        return coat_list[int(value)]
    elif(cat == 'breed'):
        return breed_list[int(value)]

# %%
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Load images from paths stored in the dataframe
def load_images(df):
    images = []
    for path in df['image']:
        #print(os.path.join(IMAGES_DIR, path))
        img = load_img(os.path.join(IMAGES_DIR, path), target_size=(RESOLUTION, RESOLUTION))
        img = img_to_array(img)
        img = np.expand_dims(img, axis=0)
        #img = cv2.imread(os.path.join(IMAGES_DIR, path), cv2.COLOR_RGB2BGR)
        #img = cv2.resize(img, (RESOLUTION, RESOLUTION))
        images.append(img.astype(np.float32) / 255.0)
        #images.append(img)
    return np.vstack(images)

# %%
images = load_images(data)

# %%
# Process data in analysis.ipynb
print(data.iloc[:, 4].shape)
print(images.shape)
# Out:
# (41939,)
# (41939, 128, 128, 3)

# %%
# Plotting 4 cats with their matching info
fig = plt.figure(figsize=(24, 10))
for i, r in enumerate([random.randint(0, images.shape[0]) for _ in range(4)]):
    ax = plt.subplot(2, 4, i + 1)
    ax.set_title(data.iloc[r, 5])
    ax.imshow(images[r])
    print(r, get_cat_string('age', data.iloc[r, 0]), get_cat_string('gender', data.iloc[r, 1]), get_cat_string('size', data.iloc[r, 2]), get_cat_string('coat', data.iloc[r, 3]))
# Out:
# 29892 Baby Male Small Short
# 24708 Adult Female Small Long
# 28467 Adult Female Medium Long
# 18579 Adult Female Medium Short

# %%
# Import ml libraries
from tensorflow.keras import models, layers, optimizers, callbacks
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import tensorflow as tf

if tf.test.gpu_device_name():
   print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
# Chekpoints callback function
def make_checkpoints(name):
    return callbacks.ModelCheckpoint(filepath=os.path.join(CHECKPOINTS_DIR,name+'.ckpt'), 
                                     save_weights_only=True, verbose=1)

# %%
# Plot graphs functions
def plot_accuracy(history, path):
    plt.plot(history.history['accuracy'], label='Accuracy')
    plt.plot(history.history['val_accuracy'], label = 'Accuracy_Val')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='best')
    plt.savefig(path)
    plt.show()
def plot_loss(history, path):
    plt.plot(history.history['loss'], label='Loss')
    plt.plot(history.history['val_loss'], label = 'Loss_Val')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='best')
    plt.savefig(path)
    plt.show()

# %%
# Datasets

# One-hot encoding
label_cols = pd.DataFrame(
    to_categorical(data[LABELS]), 
    columns=['l' + str(i+1) for i in range(len(data[LABELS].unique()))]
)
label_cols.index = data.index

# Split into 0.6:0.2:0.2
X_cat_train, X_cat_test, y_train, y_test = train_test_split(
    data.drop([LABELS], axis=1), 
    label_cols, 
    test_size=0.2, 
    random_state=1)
X_cat_train, X_cat_val, y_train, y_val = train_test_split(
    X_cat_train, y_train, test_size=0.25, random_state=1)

# Load images from paths stored in each dataframe
X_img_train = load_images(X_cat_train)
X_img_test = load_images(X_cat_test)
X_img_val = load_images(X_cat_val)

# Remove the image column containing paths
X_cat_train = X_cat_train.drop(['image'], axis=1)
X_cat_test = X_cat_test.drop(['image'], axis=1)
X_cat_val = X_cat_val.drop(['image'], axis=1)

print(X_cat_train.shape, X_cat_test.shape, X_cat_val.shape)
print(X_img_train.shape, X_img_test.shape, X_img_val.shape)
# Out:
# (25163, 4) (8388, 4) (8388, 4)
# (25163, 128, 128, 3) (8388, 128, 128, 3) (8388, 128, 128, 3)

# %%
# Correlation map for temp choice on labels
def get_corr_map(data):
    corr = data.corr()
    plt.figure(figsize=(4, 4), dpi=100, facecolor='w', edgecolor='k')
    colormap = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(colormap)
    plt.title('Correlation Map')
    plt.show()
    return corr

# %% [markdown]
# # Correlations for categorical attributes
# - Size and Gender
# - Coat and Size

# %%
get_corr_map(data)
# Out:
#              age    gender      size      coat     breed
# age     1.000000 -0.018718  0.095492  0.071828 -0.006869
# gender -0.018718  1.000000 -0.190893 -0.081781  0.035960
# size    0.095492 -0.190893  1.000000  0.137256 -0.002803
# coat    0.071828 -0.081781  0.137256  1.000000 -0.070799
# breed  -0.006869  0.035960 -0.002803 -0.070799  1.000000

# %%
get_corr_map(X_cat_train)
# Out:
#              age    gender      size     breed
# age     1.000000 -0.015417  0.100114 -0.008288
# gender -0.015417  1.000000 -0.189885  0.040378
# size    0.100114 -0.189885  1.000000 -0.010068
# breed  -0.008288  0.040378 -0.010068  1.000000

# %%
get_corr_map(X_cat_test)
# Out:
#              age    gender      size     breed
# age     1.000000 -0.018758  0.091553 -0.017600
# gender -0.018758  1.000000 -0.189517  0.028329
# size    0.091553 -0.189517  1.000000  0.005472
# breed  -0.017600  0.028329  0.005472  1.000000

# %%
get_corr_map(X_cat_val)
# Out:
#              age    gender      size     breed
# age     1.000000 -0.028693  0.085433  0.008404
# gender -0.028693  1.000000 -0.195348  0.030349
# size    0.085433 -0.195348  1.000000  0.010877
# breed   0.008404  0.030349  0.010877  1.000000

# %%
get_corr_map(pd.concat([data.drop([LABELS], axis=1), label_cols], axis=1))
# Out:
#              age    gender      size     breed        l1        l2        l3
# age     1.000000 -0.018718  0.095492 -0.006869 -0.066214 -0.012503  0.066185
# gender -0.018718  1.000000 -0.190893  0.035960  0.066169  0.035816 -0.083292
# size    0.095492 -0.190893  1.000000 -0.002803 -0.126940 -0.022927  0.126119
# breed  -0.006869  0.035960 -0.002803  1.000000  0.075811 -0.012361 -0.056160
# l1     -0.066214  0.066169 -0.126940  0.075811  1.000000 -0.222491 -0.697075
# l2     -0.012503  0.035816 -0.022927 -0.012361 -0.222491  1.000000 -0.543933
# l3      0.066185 -0.083292  0.126119 -0.056160 -0.697075 -0.543933  1.000000

# %% [markdown]
# # Networks

# %%
from tensorflow.keras import Input, Model

# %% [markdown]
# ## Test 1

# %%
# Name for outputs
test_fol = 'final_cnn_combined'
n1 = test_fol+'_1/final_cnn_combined_1'

# %%
# Categorical Features - Input Layer 1
input_cat = Input(shape=(4,))

x_cat = layers.Dense(32)(input_cat)
x_cat = layers.Dense(64)(x_cat)
x_cat = layers.Dense(128)(x_cat)

x_cat = Model(inputs=input_cat, outputs=x_cat)

x_cat.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                160
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# =================================================================
# Total params: 10,592
# Trainable params: 10,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Visual Features - Input Layer 2
input_img = Input(shape=(RESOLUTION, RESOLUTION, 3))

x_img = layers.Conv2D(32, (3, 3), activation='relu')(input_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Conv2D(128, (3, 3), activation='relu')(x_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Conv2D(128, (3, 3), activation='relu')(x_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Flatten()(x_img)
x_img = layers.Dropout(0.5)(x_img)

x_img = Model(inputs=input_img, outputs=x_img)

x_img.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# =================================================================
# Total params: 185,472
# Trainable params: 185,472
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Combine Model
combine_input = layers.Concatenate(axis=1)([x_cat.output, x_img.output])

x_combine = layers.Dense(256, activation='sigmoid')(combine_input)
x_combine = layers.Dense(len(data[LABELS].unique()), activation='softmax')(x_combine)

model_1 = Model(inputs=[x_cat.input, x_img.input], outputs = x_combine)
model_1.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 126, 126, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 63, 63, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 61, 61, 128)  36992       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 128)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  147584      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           160         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2112        dense[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          8320        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 25088)        0           flatten[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 25216)        0           dense_2[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          6455552     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            771         dense_3[0][0]
# ==================================================================================================
# Total params: 6,652,387
# Trainable params: 6,652,387
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Test 1
epochs = 1
lr = 0.003
opt = optimizers.Adam(learning_rate=lr)

model_1.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
history_1 = model_1.fit(
    x = [X_cat_train, X_img_train],
    y = y_train,
    validation_data = ([X_cat_val, X_img_val], y_val),
    epochs=epochs,
    callbacks=[make_checkpoints(n1)]
)
# Out:
# 787/787 [==============================] - 20s 22ms/step - loss: 0.5437 - accuracy: 0.6159 - val_loss: 0.5078 - val_accuracy: 0.6314
#
# Epoch 00001: saving model to ../History/final_cnn_combined_1\final_cnn_combined_1.ckpt

# %%
# Show and Export graphs
plot_accuracy(history_1, os.path.join(FIGURES_DIR, n1 + '_E_' + str(epochs) + '_acc.png'))
plot_loss(history_1, os.path.join(FIGURES_DIR, n1 + '_E_' + str(epochs) + '_loss.png'))

# %% [markdown]
# ## Test 2

# %%
# Name for outputs
n2 = test_fol+'_2/final_cnn_combined_2'
if not os.path.exists(n2.rsplit('/',1)[0]):
    os.makedirs(n2.rsplit('/',1)[0])

# %%
# Categorical Features - Input Layer 1
input_cat = Input(shape=(4,))

x_cat = layers.Dense(32)(input_cat)
x_cat = layers.Dense(32)(x_cat)
x_cat = layers.Dense(64)(x_cat)
x_cat = layers.Dense(64)(x_cat)
x_cat = layers.Dense(128)(x_cat)
x_cat = layers.Dense(128)(x_cat)

x_cat = Model(inputs=input_cat, outputs=x_cat)

x_cat.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# =================================================================
# Total params: 32,320
# Trainable params: 32,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Visual Features - Input Layer 2
input_img = Input(shape=(RESOLUTION, RESOLUTION, 3))

x_img = layers.Conv2D(32, (3, 3), activation='relu')(input_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Conv2D(128, (3, 3), activation='relu')(x_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Conv2D(128, (3, 3), activation='relu')(x_img)
x_img = layers.MaxPooling2D((2, 2))(x_img)
x_img = layers.Flatten()(x_img)
x_img = layers.Dropout(0.35)(x_img)

x_img = Model(inputs=input_img, outputs=x_img)

x_img.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 61, 61, 128)       36992
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# =================================================================
# Total params: 185,472
# Trainable params: 185,472
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Combine Model
combine_input = layers.Concatenate(axis=1)([x_cat.output, x_img.output])

x_combine = layers.Dense(512, activation='relu')(combine_input)
x_combine = layers.Dense(len(data[LABELS].unique()), activation='sigmoid')(x_combine)

model_2 = Model(inputs=[x_cat.input, x_img.input], outputs = x_combine)
model_2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 126, 126, 32) 896         input_4[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 63, 63, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           160         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 61, 61, 128)  36992       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 32)           1056        dense_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           2112        dense_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  147584      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           4160        dense_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          8320        dense_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 25088)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          16512       dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 25088)        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 25216)        0           dense_10[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 512)          12911104    concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 3)            1539        dense_11[0][0]
# ==================================================================================================
# Total params: 13,130,435
# Trainable params: 13,130,435
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 50
lr = 0.018 # 0.025 (works best so far)
bs = 16 # breaks the network
opt = optimizers.SGD(lr=lr, momentum=0.9, decay=0.01)
n2 = n2 + '_lr_'+str(lr)

model_2.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
history_2 = model_2.fit(
    x = [X_cat_train, X_img_train],
    y = y_train,
    validation_data = ([X_cat_val, X_img_val], y_val),
    batch_size=bs,
    epochs=epochs,
    callbacks=[make_checkpoints(n2)]
)
# Out:
# Epoch 1/50
# 787/787 [==============================] - 19s 23ms/step - loss: 0.5483 - accuracy: 0.6169 - val_loss: 0.4711 - val_accuracy: 0.6756
#
# Epoch 00001: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 2/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4729 - accuracy: 0.6653 - val_loss: 0.4671 - val_accuracy: 0.6899
#
# Epoch 00002: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 3/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4681 - accuracy: 0.6756 - val_loss: 0.4653 - val_accuracy: 0.6769
#
# Epoch 00003: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 4/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4635 - accuracy: 0.6877 - val_loss: 0.4616 - val_accuracy: 0.6948
#
# Epoch 00004: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 5/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4623 - accuracy: 0.6886 - val_loss: 0.4595 - val_accuracy: 0.6942
#
# Epoch 00005: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 6/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4631 - accuracy: 0.6929 - val_loss: 0.4577 - val_accuracy: 0.7022
#
# Epoch 00006: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 7/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4631 - accuracy: 0.6937 - val_loss: 0.4569 - val_accuracy: 0.7049
#
# Epoch 00007: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 8/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4556 - accuracy: 0.7029 - val_loss: 0.4555 - val_accuracy: 0.7082
#
# Epoch 00008: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 9/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4611 - accuracy: 0.6931 - val_loss: 0.4566 - val_accuracy: 0.6936
#
# Epoch 00009: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 10/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4639 - accuracy: 0.6950 - val_loss: 0.4573 - val_accuracy: 0.7003
#
# Epoch 00010: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 11/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4573 - accuracy: 0.6975 - val_loss: 0.4555 - val_accuracy: 0.6958
#
# Epoch 00011: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 12/50
# 787/787 [==============================] - 19s 24ms/step - loss: 0.4605 - accuracy: 0.6997 - val_loss: 0.4548 - val_accuracy: 0.7064
#
# Epoch 00012: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 13/50
# 787/787 [==============================] - 18s 23ms/step - loss: 0.4571 - accuracy: 0.7055 - val_loss: 0.4560 - val_accuracy: 0.7014
#
# Epoch 00013: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 14/50
# 787/787 [==============================] - 21s 27ms/step - loss: 0.4516 - accuracy: 0.7046 - val_loss: 0.4540 - val_accuracy: 0.7024
#
# Epoch 00014: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 15/50
# 787/787 [==============================] - 24s 31ms/step - loss: 0.4543 - accuracy: 0.7049 - val_loss: 0.4546 - val_accuracy: 0.7008
#
# Epoch 00015: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 16/50
# 787/787 [==============================] - 24s 31ms/step - loss: 0.4542 - accuracy: 0.7043 - val_loss: 0.4531 - val_accuracy: 0.7058
#
# Epoch 00016: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 17/50
# 787/787 [==============================] - 24s 31ms/step - loss: 0.4558 - accuracy: 0.7014 - val_loss: 0.4527 - val_accuracy: 0.7072
#
# Epoch 00017: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 18/50
# 787/787 [==============================] - 24s 31ms/step - loss: 0.4519 - accuracy: 0.7052 - val_loss: 0.4531 - val_accuracy: 0.7036
#
# Epoch 00018: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 19/50
# 787/787 [==============================] - 24s 31ms/step - loss: 0.4563 - accuracy: 0.7002 - val_loss: 0.4532 - val_accuracy: 0.7014
#
# Epoch 00019: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 20/50
# 787/787 [==============================] - 23s 30ms/step - loss: 0.4565 - accuracy: 0.6989 - val_loss: 0.4536 - val_accuracy: 0.7061
#
# Epoch 00020: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 21/50
# 787/787 [==============================] - 23s 30ms/step - loss: 0.4544 - accuracy: 0.7020 - val_loss: 0.4525 - val_accuracy: 0.7084
#
# Epoch 00021: saving model to ../History/final_cnn_combined_2\final_cnn_combined_2_lr_0.018.ckpt
# Epoch 22/50
# 786/787 [============================>.] - ETA: 0s - loss: 0.4559 - accuracy: 0.7009

# %%
# Show and Export graphs
plot_accuracy(history_2, os.path.join(FIGURES_DIR, n2 + '_E_' + str(epochs) + '_lr_'+str(lr)+'_acc.png'))
plot_loss(history_2, os.path.join(FIGURES_DIR, n2 + '_E_' + str(epochs) + '_lr_'+str(lr)+'_loss.png'))

# %% [markdown]
# - Dropout value for CNN is a little bit higher

# %% [markdown]
# ## Test 3

# %% [markdown]
# ## Test 4
